# %% [markdown]
# <div style="background:rgba(14,165,233,0.08);border:1px solid rgba(14,165,233,0.35);border-left:4px solid rgba(14,165,233,0.9);padding:10px 12px;border-radius:8px;">
# <strong style="color:inherit;">Create Empty Lists</strong><br>
# <span style="color:inherit;">Initialize empty list variables.</span>
# </div>

# %%
l = []
myl = []

# %% [markdown]
# <div style="background:rgba(14,165,233,0.08);border:1px solid rgba(14,165,233,0.35);border-left:4px solid rgba(14,165,233,0.9);padding:10px 12px;border-radius:8px;">
# <strong style="color:inherit;">Mixed-Type List</strong><br>
# <span style="color:inherit;">Create a list with various data types.</span>
# </div>

# %%
myl = ["iti", 32, 324.3, True, ["python", "kubernates", 'jenkins'], None , "iti"]

# %% [markdown]
# <div style="background:rgba(14,165,233,0.08);border:1px solid rgba(14,165,233,0.35);border-left:4px solid rgba(14,165,233,0.9);padding:10px 12px;border-radius:8px;">
# <strong style="color:inherit;">List Length</strong><br>
# <span style="color:inherit;">Count the number of elements in the list.</span>
# </div>

# %%
print(len(myl))
# Out:
# 7

# %% [markdown]
# <div style="background:rgba(14,165,233,0.08);border:1px solid rgba(14,165,233,0.35);border-left:4px solid rgba(14,165,233,0.9);padding:10px 12px;border-radius:8px;">
# <strong style="color:inherit;">Count a Value</strong><br>
# <span style="color:inherit;">Count how many times a value appears.</span>
# </div>

# %%
print(myl.count("iti"))
# Out:
# 2

# %% [markdown]
# <div style="background:rgba(14,165,233,0.08);border:1px solid rgba(14,165,233,0.35);border-left:4px solid rgba(14,165,233,0.9);padding:10px 12px;border-radius:8px;">
# <strong style="color:inherit;">Index Access</strong><br>
# <span style="color:inherit;">Retrieve an element by its index.</span>
# </div>

# %%
# get element at index
myl[2]
# Out:
# 324.3

# %% [markdown]
# <div style="background:rgba(14,165,233,0.08);border:1px solid rgba(14,165,233,0.35);border-left:4px solid rgba(14,165,233,0.9);padding:10px 12px;border-radius:8px;">
# <strong style="color:inherit;">Mutate an Item</strong><br>
# <span style="color:inherit;">Update a list element by index.</span>
# </div>

# %%
# list is mutable datatype
myl[2] = "updated value"
print(myl)
# Out:
# ['iti', 32, 'updated value', True, ['python', 'kubernates', 'jenkins'], None, 'iti']

# %% [markdown]
# <div style="background:rgba(14,165,233,0.08);border:1px solid rgba(14,165,233,0.35);border-left:4px solid rgba(14,165,233,0.9);padding:10px 12px;border-radius:8px;">
# <strong style="color:inherit;">Out-of-Range Assignment</strong><br>
# <span style="color:inherit;">Attempt to assign beyond the list length.</span>
# </div>

# %%
myl[100] = "updated value"
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 myl[100] = "updated value"
#
# IndexError: list assignment index out of range

# %% [markdown]
# <div style="background:rgba(14,165,233,0.08);border:1px solid rgba(14,165,233,0.35);border-left:4px solid rgba(14,165,233,0.9);padding:10px 12px;border-radius:8px;">
# <strong style="color:inherit;">Empty Code Cell</strong><br>
# <span style="color:inherit;">Placeholder for future list examples.</span>
# </div>

# %% [markdown]
# <div style="background:rgba(14,165,233,0.08);border:1px solid rgba(14,165,233,0.35);border-left:4px solid rgba(14,165,233,0.9);padding:10px 12px;border-radius:8px;">
# <strong style="color:inherit;">Find Index</strong><br>
# <span style="color:inherit;">Locate the first occurrence of a value.</span>
# </div>

# %%
# get index of element
print(myl.index("iti"))
# Out:
# 0

# %% [markdown]
# <div style="background:rgba(14,165,233,0.08);border:1px solid rgba(14,165,233,0.35);border-left:4px solid rgba(14,165,233,0.9);padding:10px 12px;border-radius:8px;">
# <strong style="color:inherit;">Iterate Items</strong><br>
# <span style="color:inherit;">Loop through list elements.</span>
# </div>

# %%
# list is iterable
for item in myl:
    print(f"item = {item} ")
# Out:
# item = iti
# item = 32
# item = updated value
# item = True
# item = ['python', 'kubernates', 'jenkins']
# item = None
# item = iti

# %% [markdown]
# <div style="background:rgba(14,165,233,0.08);border:1px solid rgba(14,165,233,0.35);border-left:4px solid rgba(14,165,233,0.9);padding:10px 12px;border-radius:8px;">
# <strong style="color:inherit;">Enumerate Items</strong><br>
# <span style="color:inherit;">Loop with index and value pairs.</span>
# </div>

# %%
for index,  item in enumerate(myl):
    print(f"index : {index} .. item = {item} ")
# Out:
# index : 0 .. item = iti
# index : 1 .. item = 32
# index : 2 .. item = updated value
# index : 3 .. item = True
# index : 4 .. item = ['python', 'kubernates', 'jenkins']
# index : 5 .. item = None
# index : 6 .. item = iti

# %% [markdown]
# <div style="background:rgba(14,165,233,0.08);border:1px solid rgba(14,165,233,0.35);border-left:4px solid rgba(14,165,233,0.9);padding:10px 12px;border-radius:8px;">
# <strong style="color:inherit;">Membership Test</strong><br>
# <span style="color:inherit;">Check if a value exists in the list.</span>
# </div>

# %%
# element exists in list ?
print("noha" in myl)
# Out:
# False

# %% [markdown]
# <div style="background:rgba(14,165,233,0.08);border:1px solid rgba(14,165,233,0.35);border-left:4px solid rgba(14,165,233,0.9);padding:10px 12px;border-radius:8px;">
# <strong style="color:inherit;">Empty Code Cell</strong><br>
# <span style="color:inherit;">Placeholder for additional list notes.</span>
# </div>

# %% [markdown]
# <div style="background:rgba(14,165,233,0.08);border:1px solid rgba(14,165,233,0.35);border-left:4px solid rgba(14,165,233,0.9);padding:10px 12px;border-radius:8px;">
# <strong style="color:inherit;">Mutability Reminder</strong><br>
# <span style="color:inherit;">Note that lists are mutable in Python.</span>
# </div>

# %% [markdown]
# # List is mutable

# %% [markdown]
# <div style="background:rgba(14,165,233,0.08);border:1px solid rgba(14,165,233,0.35);border-left:4px solid rgba(14,165,233,0.9);padding:10px 12px;border-radius:8px;">
# <strong style="color:inherit;">Append Item</strong><br>
# <span style="color:inherit;">Add a new element to the end of the list.</span>
# </div>

# %%
myl.append("Omar")
print(myl)
# Out:
# ['iti', 32, 'updated value', True, ['python', 'kubernates', 'jenkins'], None, 'iti', 'Omar']

# %% [markdown]
# <div style="background:rgba(14,165,233,0.08);border:1px solid rgba(14,165,233,0.35);border-left:4px solid rgba(14,165,233,0.9);padding:10px 12px;border-radius:8px;">
# <strong style="color:inherit;">Insert at Index</strong><br>
# <span style="color:inherit;">Insert a value at a specific position.</span>
# </div>

# %%
myl.insert(3, 'Roaa')
print(myl)
# Out:
# ['iti', 32, 'updated value', 'Roaa', True, ['python', 'kubernates', 'jenkins'], None, 'iti', 'Omar']

# %% [markdown]
# <div style="background:rgba(14,165,233,0.08);border:1px solid rgba(14,165,233,0.35);border-left:4px solid rgba(14,165,233,0.9);padding:10px 12px;border-radius:8px;">
# <strong style="color:inherit;">Insert Past End</strong><br>
# <span style="color:inherit;">Insert at a large index to append at the end.</span>
# </div>

# %%
myl.insert(100, 'anyvalue')
print(myl)
# Out:
# ['iti', 32, 'updated value', 'Roaa', True, ['python', 'kubernates', 'jenkins'], None, 'iti', 'Omar', 'anyvalue']

# %% [markdown]
# <div style="background:rgba(14,165,233,0.08);border:1px solid rgba(14,165,233,0.35);border-left:4px solid rgba(14,165,233,0.9);padding:10px 12px;border-radius:8px;">
# <strong style="color:inherit;">Pop Last Item</strong><br>
# <span style="color:inherit;">Remove and return the last list element.</span>
# </div>

# %%
popped_element =myl.pop()
print(myl)
print(popped_element)
# Out:
# ['iti', 32, 'updated value', 'Roaa', True, ['python', 'kubernates', 'jenkins'], None, 'iti', 'Omar']
# anyvalue

# %% [markdown]
# <div style="background:rgba(14,165,233,0.08);border:1px solid rgba(14,165,233,0.35);border-left:4px solid rgba(14,165,233,0.9);padding:10px 12px;border-radius:8px;">
# <strong style="color:inherit;">Pop by Index</strong><br>
# <span style="color:inherit;">Remove and return an element at a specific index.</span>
# </div>

# %%
popped_element = myl.pop(3)
print(myl)
print(popped_element)
# Out:
# ['iti', 32, 'updated value', True, ['python', 'kubernates', 'jenkins'], None, 'iti', 'Omar']
# Roaa

# %% [markdown]
# <div style="background:rgba(14,165,233,0.08);border:1px solid rgba(14,165,233,0.35);border-left:4px solid rgba(14,165,233,0.9);padding:10px 12px;border-radius:8px;">
# <strong style="color:inherit;">Remove by Value</strong><br>
# <span style="color:inherit;">Delete the first matching element.</span>
# </div>

# %%
# I know the item ?
myl.remove("iti")
print(myl)
# Out:
# [32, 'updated value', True, ['python', 'kubernates', 'jenkins'], None, 'iti', 'Omar']

# %% [markdown]
# <div style="background:rgba(14,165,233,0.08);border:1px solid rgba(14,165,233,0.35);border-left:4px solid rgba(14,165,233,0.9);padding:10px 12px;border-radius:8px;">
# <strong style="color:inherit;">Remove All Matches</strong><br>
# <span style="color:inherit;">Loop to remove every occurrence of a value.</span>
# </div>

# %%
for item in myl:
    if item =='iti':
        myl.remove(item)


while  "iti" in myl:
    myl.remove("iti")

# %% [markdown]
# <div style="background:rgba(14,165,233,0.08);border:1px solid rgba(14,165,233,0.35);border-left:4px solid rgba(14,165,233,0.9);padding:10px 12px;border-radius:8px;">
# <strong style="color:inherit;">Sort the List</strong><br>
# <span style="color:inherit;">Sort elements in place (same type required).</span>
# </div>

# %%
# sorting the list items , sorting  requires elements to be from the same type
print(myl)
myl.sort()
print(myl)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 3
#       1 # sorting the list items
#       2 print(myl)
# ----> 3 myl.sort()
#       4 print(myl)
#
# TypeError: '<' not supported between instances of 'str' and 'int'

# %% [markdown]
# <div style="background:rgba(14,165,233,0.08);border:1px solid rgba(14,165,233,0.35);border-left:4px solid rgba(14,165,233,0.9);padding:10px 12px;border-radius:8px;">
# <strong style="color:inherit;">Sort String List</strong><br>
# <span style="color:inherit;">Sort course names alphabetically.</span>
# </div>

# %%
courses =  ['python', 'kubernates', 'jenkins']
courses.sort()
print(courses)

# sorted()
# Out:
# ['jenkins', 'kubernates', 'python']

# %% [markdown]
# <div style="background:rgba(14,165,233,0.08);border:1px solid rgba(14,165,233,0.35);border-left:4px solid rgba(14,165,233,0.9);padding:10px 12px;border-radius:8px;">
# <strong style="color:inherit;">Reverse Sort</strong><br>
# <span style="color:inherit;">Sort the list in descending order.</span>
# </div>

# %%
courses.sort(reverse=True)
print(courses)
# Out:
# ['python', 'kubernates', 'jenkins']

# %% [markdown]
# <div style="background:rgba(14,165,233,0.08);border:1px solid rgba(14,165,233,0.35);border-left:4px solid rgba(14,165,233,0.9);padding:10px 12px;border-radius:8px;">
# <strong style="color:inherit;">Reverse List</strong><br>
# <span style="color:inherit;">Reverse the list order in place.</span>
# </div>

# %%
print(myl)
myl.reverse()
print(myl)
# Out:
# [32, 'updated value', True, ['python', 'kubernates', 'jenkins'], None, 'iti', 'Omar']
# ['Omar', 'iti', None, ['python', 'kubernates', 'jenkins'], True, 'updated value', 32]

# %% [markdown]
# <div style="background:rgba(14,165,233,0.08);border:1px solid rgba(14,165,233,0.35);border-left:4px solid rgba(14,165,233,0.9);padding:10px 12px;border-radius:8px;">
# <strong style="color:inherit;">Nested List Access</strong><br>
# <span style="color:inherit;">Access an element inside a nested list.</span>
# </div>

# %%
print(myl[3][1])
# Out:
# kubernates

# %% [markdown]
# <div style="background:rgba(14,165,233,0.08);border:1px solid rgba(14,165,233,0.35);border-left:4px solid rgba(14,165,233,0.9);padding:10px 12px;border-radius:8px;">
# <strong style="color:inherit;">Concatenate Lists</strong><br>
# <span style="color:inherit;">Join two lists using + and +=.</span>
# </div>

# %%
# concat 2 lists
l1 = [23,2,43]
l2 = [23,'24','dsd']
l3 = l1+l2
print(l3)

l1 += l2 # re-assign ,,, l1 = l1+l2
# Out:
# [23, 2, 43, 23, '24', 'dsd']

# %% [markdown]
# <div style="background:rgba(14,165,233,0.08);border:1px solid rgba(14,165,233,0.35);border-left:4px solid rgba(14,165,233,0.9);padding:10px 12px;border-radius:8px;">
# <strong style="color:inherit;">Extend a List</strong><br>
# <span style="color:inherit;">Add multiple items from another list.</span>
# </div>

# %%
# extend a list
courses =  ['python', 'kubernetes', 'jenkins']
extra_courses = ["PS", "IS", "JS"]

courses.extend(extra_courses)
print(courses)
# Out:
# ['python', 'kubernetes', 'jenkins', 'PS', 'IS', 'JS']

# %% [markdown]
# <div style="background:rgba(14,165,233,0.08);border:1px solid rgba(14,165,233,0.35);border-left:4px solid rgba(14,165,233,0.9);padding:10px 12px;border-radius:8px;">
# <strong style="color:inherit;">Minimum Value</strong><br>
# <span style="color:inherit;">Find the smallest number in a list.</span>
# </div>

# %%
x = [5,66,77]
print(min(x))
# Out:
# 5

# %% [markdown]
# <div style="background:rgba(14,165,233,0.08);border:1px solid rgba(14,165,233,0.35);border-left:4px solid rgba(14,165,233,0.9);padding:10px 12px;border-radius:8px;">
# <strong style="color:inherit;">String to List</strong><br>
# <span style="color:inherit;">Convert a string into a list of characters.</span>
# </div>

# %%
# cast string to a list
message = 'The lecture is interesting'
print(list(message))
# Out:
# ['T', 'h', 'e', ' ', 'l', 'e', 'c', 't', 'u', 'r', 'e', ' ', 'i', 's', ' ', 'i', 'n', 't', 'e', 'r', 'e', 's', 't', 'i', 'n', 'g']

# %% [markdown]
# <div style="background:rgba(14,165,233,0.08);border:1px solid rgba(14,165,233,0.35);border-left:4px solid rgba(14,165,233,0.9);padding:10px 12px;border-radius:8px;">
# <strong style="color:inherit;">Split to Words</strong><br>
# <span style="color:inherit;">Split a sentence into a list of words.</span>
# </div>

# %%
# split string to words

print(message.split(" "))
# Out:
# ['The', 'lecture', 'is', 'interesting']

# %% [markdown]
# <div style="background:rgba(14,165,233,0.08);border:1px solid rgba(14,165,233,0.35);border-left:4px solid rgba(14,165,233,0.9);padding:10px 12px;border-radius:8px;">
# <strong style="color:inherit;">Empty Code Cell</strong><br>
# <span style="color:inherit;">Placeholder for more list operations.</span>
# </div>
