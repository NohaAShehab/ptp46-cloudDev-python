# %% [markdown]
# <div style="background:#f3e5f5;border-left:4px solid #8e24aa;padding:6px 10px;border-radius:6px"><b>Next cell (markdown)</b><br><span style="color:#546e7a">Text:</span> # inheritance</div>

# %% [markdown]
# # inheritance

# %% [markdown]
# <div style="background:#e3f2fd;border-left:4px solid #1e88e5;padding:6px 10px;border-radius:6px"><b>Next cell (code)</b><br><span style="color:#546e7a">Snippet:</span> <code>from pygments.lexers.sql import re_prompt</code></div>

# %%
from pygments.lexers.sql import re_prompt


class Person:
    pass

class Engineer(Person):
    pass

# represent is-a relationship
e = Engineer()
print(isinstance(e, Engineer), isinstance(e, Person))
# Out:
# True True

# %% [markdown]
# <div style="background:#e3f2fd;border-left:4px solid #1e88e5;padding:6px 10px;border-radius:6px"><b>Next cell (code)</b><br><span style="color:#546e7a">Snippet:</span> <code>class Person:</code></div>

# %%
class Person:
    def __init__(self, name):
        self.name = name
        print('I am a person')

class Engineer(Person):
    pass

e = Engineer()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 9
#       6 class Engineer(Person):
#       7     pass
# ----> 9 e = Engineer()
#
# TypeError: Person.__init__() missing 1 required positional argument: 'name'

# %% [markdown]
# <div style="background:#e3f2fd;border-left:4px solid #1e88e5;padding:6px 10px;border-radius:6px"><b>Next cell (code)</b><br><span style="color:#546e7a">Snippet:</span> <code>e = Engineer("noha")</code></div>

# %%
e = Engineer("noha")
print(e.__dict__)
# Out:
# I am a person
# {'name': 'noha'}

# %% [markdown]
# <div style="background:#e3f2fd;border-left:4px solid #1e88e5;padding:6px 10px;border-radius:6px"><b>Next cell (code)</b><br><span style="color:#546e7a">Snippet:</span> <code>class Person:</code></div>

# %%
class Person:
    def __init__(self, name):
        self.name = name
        print('I am a person')

class Engineer(Person):
    def __init__(self, salary):
        self.salary = salary

e = Engineer()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 10
#       7     def __init__(self, salary):
#       8         self.salary = salary
# ---> 10 e = Engineer()
#
# TypeError: Engineer.__init__() missing 1 required positional argument: 'salary'

# %% [markdown]
# <div style="background:#e3f2fd;border-left:4px solid #1e88e5;padding:6px 10px;border-radius:6px"><b>Next cell (code)</b><br><span style="color:#546e7a">Snippet:</span> <code>e = Engineer(12132)</code></div>

# %%
e = Engineer(12132)
print(e.__dict__)
# Out:
# {'salary': 12132}

# %% [markdown]
# <div style="background:#e3f2fd;border-left:4px solid #1e88e5;padding:6px 10px;border-radius:6px"><b>Next cell (code)</b><br><span style="color:#546e7a">Snippet:</span> <code>print(e.__dict__)</code></div>

# %%
print(e.__dict__)


class Person:
    def __init__(self, name):
        self.name = name
        print('I am a person')

    def say_hello(self):
        print(f"Hello I am {self.name}!")


class Engineer(Person):
    def __init__(self, salary):
        self.salary = salary

ee  = Engineer(214355)
# Out:
# {'salary': 12132}

# %% [markdown]
# <div style="background:#e3f2fd;border-left:4px solid #1e88e5;padding:6px 10px;border-radius:6px"><b>Next cell (code)</b><br><span style="color:#546e7a">Snippet:</span> <code>ee.say_hello()</code></div>

# %%
ee.say_hello()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 ee.say_hello()
#
# Cell In[11], line 10, in Person.say_hello(self)
#       9 def say_hello(self):
# ---> 10     print(f"Hello I am {self.name}!")
#
# AttributeError: 'Engineer' object has no attribute 'name'

# %% [markdown]
# <div style="background:#e3f2fd;border-left:4px solid #1e88e5;padding:6px 10px;border-radius:6px"><b>Next cell (code)</b><br><span style="color:#546e7a">Snippet:</span> <code>class Person:</code></div>

# %%
class Person:
    def __init__(self, name):
        self.name = name
        print('I am a person')

    def say_hello(self):
        print(f"Hello I am {self.name}!")


class Engineer(Person):
    def __init__(self,name, salary):
        # calling parent constructor
        super().__init__(name)
        self.salary = salary

ee  = Engineer('Noha',214355)
ee.say_hello()
# Out:
# I am a person
# Hello I am Noha!

# %% [markdown]
# <div style="background:#f3e5f5;border-left:4px solid #8e24aa;padding:6px 10px;border-radius:6px"><b>Next cell (markdown)</b><br><span style="color:#546e7a">Text:</span> ### Python supports multiple inheritance</div>

# %% [markdown]
# ### Python supports multiple inheritance

# %% [markdown]
# <div style="background:#e3f2fd;border-left:4px solid #1e88e5;padding:6px 10px;border-radius:6px"><b>Next cell (code)</b><br><span style="color:#546e7a">Snippet:</span> <code>class A:</code></div>

# %%
class A:
    pass

class B:
    pass

class C(A, B): pass

c = C()
print(isinstance(c, A), isinstance(c, B), isinstance(c, C))
# Out:
# True True True

# %% [markdown]
# <div style="background:#e3f2fd;border-left:4px solid #1e88e5;padding:6px 10px;border-radius:6px"><b>Next cell (code)</b><br><span style="color:#546e7a">Snippet:</span> <code>### Python supports multiple inheritance</code></div>

# %%
### Python supports multiple inheritance
class A: pass

class B:
    def __init__(self, name='b'):
        self.name = name
        print("I am a b object")


class C(A, B): pass

c =C()
# Out:
# I am a b object

# %% [markdown]
# <div style="background:#e3f2fd;border-left:4px solid #1e88e5;padding:6px 10px;border-radius:6px"><b>Next cell (code)</b><br><span style="color:#546e7a">Snippet:</span> <code>class A:</code></div>

# %%
class A:
    def __init__(self, name='a'):
        self.name = name
        print("I am a A object")

class B:
    def __init__(self, name='b'):
        self.name = name
        print("I am a B object")


class C(A, B): pass

c =C()
# Out:
# I am a A object

# %% [markdown]
# <div style="background:#e3f2fd;border-left:4px solid #1e88e5;padding:6px 10px;border-radius:6px"><b>Next cell (code)</b><br><span style="color:#546e7a">Snippet:</span> <code>class A:</code></div>

# %%
class A:
    def __init__(self, name='a'):
        self.name = name
        print("I am a A object")

class B:
    def __init__(self, age='b'):
        self.age = age
        print("I am a B object")


class C(A, B):
    def __init__(self, track='c'):
        self.track = track
        print("I am a C object")

c =C()
# Out:
# I am a C object

# %% [markdown]
# <div style="background:#e3f2fd;border-left:4px solid #1e88e5;padding:6px 10px;border-radius:6px"><b>Next cell (code)</b><br><span style="color:#546e7a">Snippet:</span> <code>class A:</code></div>

# %%
class A:
    def __init__(self, name='a'):
        self.name = name
        print("I am a A object")

class B:
    def __init__(self, age='b'):
        self.age = age
        print("I am a B object")


class C(A, B):
    def __init__(self, track='c'):
        super().__init__()
        self.track = track
        print("I am a C object")

c =C()
print(c.__dict__)
# Out:
# I am a A object
# I am a C object
# {'name': 'a', 'track': 'c'}

# %% [markdown]
# <div style="background:#e3f2fd;border-left:4px solid #1e88e5;padding:6px 10px;border-radius:6px"><b>Next cell (code)</b><br><span style="color:#546e7a">Snippet:</span> <code>class Basic:</code></div>

# %%
class Basic:
    def __init__(self, info='basic'):
        self.info = info
        print("I am a Basic object")
class A(Basic):
    def __init__(self, name='a'):
        self.name = name
        print("I am a A object")

class B(Basic):
    def __init__(self, age='b'):
        self.age = age
        print("I am a B object")


class C(A, B):
    def __init__(self, track='c'):
        super().__init__()
        self.track = track
        print("I am a C object")

c= C()
print(isinstance(c, Basic))
print(c.__dict__)
# Out:
# I am a A object
# I am a C object
# True
# {'name': 'a', 'track': 'c'}

# %% [markdown]
# <div style="background:#e3f2fd;border-left:4px solid #1e88e5;padding:6px 10px;border-radius:6px"><b>Next cell (code)</b><br><span style="color:#546e7a">Snippet:</span> <code>class Basic:</code></div>

# %%
class Basic:
    def __init__(self, info='basic'):
        self.info = info
        print("I am a Basic object")
class A(Basic):
    def __init__(self, name='a'):
        super().__init__()
        self.name = name
        print("I am a A object")

class B(Basic):
    def __init__(self, age='b'):
        self.age = age
        print("I am a B object")


class C(A, B):
    def __init__(self, track='c'):
        super().__init__()
        self.track = track
        print("I am a C object")

c= C()
print(isinstance(c, Basic))
print(c.__dict__)
# Out:
# I am a B object
# I am a A object
# I am a C object
# True
# {'age': 'b', 'name': 'a', 'track': 'c'}

# %% [markdown]
# <div style="background:#e3f2fd;border-left:4px solid #1e88e5;padding:6px 10px;border-radius:6px"><b>Next cell (code)</b><br><span style="color:#546e7a">Snippet:</span> <code>class Basic:</code></div>

# %%
class Basic:
    def __init__(self, info='basic'):
        self.info = info
        print("I am a Basic object")
class A(Basic):
    def __init__(self, name='a'):
        super().__init__()
        self.name = name
        print("I am a A object")

class B(Basic):
    def __init__(self, age='b'):
        super().__init__()
        self.age = age
        print("I am a B object")


class C(A, B):
    def __init__(self, track='c'):
        super().__init__()
        self.track = track
        print("I am a C object")

c= C()
print(isinstance(c, Basic))
print(c.__dict__)
# Out:
# I am a Basic object
# I am a B object
# I am a A object
# I am a C object
# True
# {'info': 'basic', 'age': 'b', 'name': 'a', 'track': 'c'}

# %% [markdown]
# <div style="background:#e3f2fd;border-left:4px solid #1e88e5;padding:6px 10px;border-radius:6px"><b>Next cell (code)</b><br><span style="color:#546e7a">Snippet:</span> <code>Empty cell</code></div>

# %% [markdown]
# <div style="background:#f3e5f5;border-left:4px solid #8e24aa;padding:6px 10px;border-radius:6px"><b>Next cell (markdown)</b><br><span style="color:#546e7a">Text:</span> # polymorphism</div>

# %% [markdown]
# # polymorphism
# - overriding
# - overloading

# %% [markdown]
# <div style="background:#e3f2fd;border-left:4px solid #1e88e5;padding:6px 10px;border-radius:6px"><b>Next cell (code)</b><br><span style="color:#546e7a">Snippet:</span> <code>class Person:</code></div>

# %%
class Person:
    def __init__(self, name):
        self.name = name

    def speak(self):
        print(f"My name is {self.name}")


class Employee(Person):
    def __init__(self, name, position):
        super().__init__(name)
        self.position = position

    def speak(self):
        print(f"I am working as  {self.position}")


emp =Employee("Ahmed","Manager")
emp.speak()
# Out:
# I am working as  Manager

# %% [markdown]
# <div style="background:#e3f2fd;border-left:4px solid #1e88e5;padding:6px 10px;border-radius:6px"><b>Next cell (code)</b><br><span style="color:#546e7a">Snippet:</span> <code>class Person:</code></div>

# %%
class Person:
    def __init__(self, name):
        self.name = name

    def speak(self):
        print(f"My name is {self.name}")


class Employee(Person):
    def __init__(self, name, position):
        super().__init__(name)
        self.position = position

    def speak(self):
        super().speak()
        print(f"I am working as  {self.position}")


emp =Employee("Ahmed","Manager")
emp.speak()
# Out:
# My name is Ahmed
# I am working as  Manager

# %% [markdown]
# <div style="background:#e3f2fd;border-left:4px solid #1e88e5;padding:6px 10px;border-radius:6px"><b>Next cell (code)</b><br><span style="color:#546e7a">Snippet:</span> <code># overloading ?</code></div>

# %%
# overloading ?
class Test:
    def abc(self, var1):
        if isinstance(var1, int):
            print(var1*2)
        elif isinstance(var1, float):
            print(var1/2)
        elif isinstance(var1, str):
            print(var1)
        else:
            raise Exception('--- not allowed value ---')

# %% [markdown]
# <div style="background:#e3f2fd;border-left:4px solid #1e88e5;padding:6px 10px;border-radius:6px"><b>Next cell (code)</b><br><span style="color:#546e7a">Snippet:</span> <code>from functools import singledispatch</code></div>

# %%
from functools import singledispatch

@singledispatch
def process(value):
        return value

@process.register
def _( value:str):
    return value.upper()

@process.register
def _( value:int):
    return value*10

print(process('abc'))
print(process(10))
print(process([33.444, 77]))
# Out:
# ABC
# 100
# [33.444, 77]

# %% [markdown]
# <div style="background:#e3f2fd;border-left:4px solid #1e88e5;padding:6px 10px;border-radius:6px"><b>Next cell (code)</b><br><span style="color:#546e7a">Snippet:</span> <code>from functools import singledispatchmethod</code></div>

# %%
from functools import singledispatchmethod


class Test:
    @singledispatchmethod
    def print_val(self, value):
        return f"unsupported type {value}"

    @print_val.register
    def _(self, value:int):
        print(value*10, "integer value")

    @print_val.register
    def _(self, value:str):
        print(value.upper(), "string value")

t = Test()
t.print_val(3)
# Out:
# 30 integer value

# %% [markdown]
# <div style="background:#e3f2fd;border-left:4px solid #1e88e5;padding:6px 10px;border-radius:6px"><b>Next cell (code)</b><br><span style="color:#546e7a">Snippet:</span> <code>t.print_val("iti")</code></div>

# %%
t.print_val("iti")
# Out:
# ITI string value

# %% [markdown]
# <div style="background:#e3f2fd;border-left:4px solid #1e88e5;padding:6px 10px;border-radius:6px"><b>Next cell (code)</b><br><span style="color:#546e7a">Snippet:</span> <code>t.print_val(5.44)</code></div>

# %%
t.print_val(5.44)
# Out:
# 'unsupported type 5.44'

# %% [markdown]
# <div style="background:#e3f2fd;border-left:4px solid #1e88e5;padding:6px 10px;border-radius:6px"><b>Next cell (code)</b><br><span style="color:#546e7a">Snippet:</span> <code>"""</code></div>

# %%
"""
    sum_num(int num1)

    sum_num(str num1)

"""

# %% [markdown]
# <div style="background:#f3e5f5;border-left:4px solid #8e24aa;padding:6px 10px;border-radius:6px"><b>Next cell (markdown)</b><br><span style="color:#546e7a">Text:</span> # Encapsulation</div>

# %% [markdown]
# # Encapsulation

# %% [markdown]
# <div style="background:#e3f2fd;border-left:4px solid #1e88e5;padding:6px 10px;border-radius:6px"><b>Next cell (code)</b><br><span style="color:#546e7a">Snippet:</span> <code>"""</code></div>

# %%
"""
 wrap data and functionality in one container ?
 limit accessibility data ?? access properties using object/instance
 decide where the data could be read/ modified
 -> access modifiers public, protected, private

"""
"""
    in Python --> No access modifiers
    naming variable (function, variable)
    [a-z] ==> public
    [_:] ==> protected
    [__] ==> private

"""

# %% [markdown]
# <div style="background:#e3f2fd;border-left:4px solid #1e88e5;padding:6px 10px;border-radius:6px"><b>Next cell (code)</b><br><span style="color:#546e7a">Snippet:</span> <code>class Employee:</code></div>

# %%
class Employee:
    def __init__(self, name, email, salary):
        self.name = name # public
        self._email = email  # protected
        self.__salary = salary # private

    def display_employee(self):
        print(f"name={self.name}, email={self._email}, salary={self.__salary}")

emp = Employee("Ahmed","ahmed@gmail.com", 20000)
emp.display_employee()
# Out:
# name=Ahmed, email=ahmed@gmail.com, salary=20000

# %% [markdown]
# <div style="background:#e3f2fd;border-left:4px solid #1e88e5;padding:6px 10px;border-radius:6px"><b>Next cell (code)</b><br><span style="color:#546e7a">Snippet:</span> <code>print(emp.name)</code></div>

# %%
print(emp.name)
# Out:
# Ahmed

# %% [markdown]
# <div style="background:#e3f2fd;border-left:4px solid #1e88e5;padding:6px 10px;border-radius:6px"><b>Next cell (code)</b><br><span style="color:#546e7a">Snippet:</span> <code>print(emp._email)</code></div>

# %%
print(emp._email)
# Out:
# ahmed@gmail.com

# %% [markdown]
# <div style="background:#e3f2fd;border-left:4px solid #1e88e5;padding:6px 10px;border-radius:6px"><b>Next cell (code)</b><br><span style="color:#546e7a">Snippet:</span> <code>print(emp.__salary)  # 'Employee' object has no attribute '__salary'</code></div>

# %%
print(emp.__salary)  # 'Employee' object has no attribute '__salary'
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 print(emp.__salary)
#
# AttributeError: 'Employee' object has no attribute '__salary'

# %% [markdown]
# <div style="background:#e3f2fd;border-left:4px solid #1e88e5;padding:6px 10px;border-radius:6px"><b>Next cell (code)</b><br><span style="color:#546e7a">Snippet:</span> <code>print(emp.city)</code></div>

# %%
print(emp.city)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 print(emp.city)
#
# AttributeError: 'Employee' object has no attribute 'city'

# %% [markdown]
# <div style="background:#e3f2fd;border-left:4px solid #1e88e5;padding:6px 10px;border-radius:6px"><b>Next cell (code)</b><br><span style="color:#546e7a">Snippet:</span> <code>print(emp.__dict__)</code></div>

# %%
print(emp.__dict__)
# Out:
# {'name': 'Ahmed', '_email': 'ahmed@gmail.com', '_Employee__salary': 20000}

# %% [markdown]
# <div style="background:#e3f2fd;border-left:4px solid #1e88e5;padding:6px 10px;border-radius:6px"><b>Next cell (code)</b><br><span style="color:#546e7a">Snippet:</span> <code>print(emp._Employee__salary)# don't ever do this</code></div>

# %%
print(emp._Employee__salary)# don't ever do this
# Out:
# 20000

# %% [markdown]
# <div style="background:#e3f2fd;border-left:4px solid #1e88e5;padding:6px 10px;border-radius:6px"><b>Next cell (code)</b><br><span style="color:#546e7a">Snippet:</span> <code>emp._Employee__salary = 100000  # don't ever do this</code></div>

# %%
emp._Employee__salary = 100000  # don't ever do this
emp._email='test@gmail.com' # don't ever do this

# %% [markdown]
# <div style="background:#f3e5f5;border-left:4px solid #8e24aa;padding:6px 10px;border-radius:6px"><b>Next cell (markdown)</b><br><span style="color:#546e7a">Text:</span> &lt;h1 style='color:orange'&gt; Setters and getters &lt;/h1&gt;</div>

# %% [markdown]
# <h1 style='color:orange'> Setters and getters </h1>

# %% [markdown]
# <div style="background:#e3f2fd;border-left:4px solid #1e88e5;padding:6px 10px;border-radius:6px"><b>Next cell (code)</b><br><span style="color:#546e7a">Snippet:</span> <code>class Employee:</code></div>

# %%
class Employee:
    def __init__(self, name, email, salary):
        self.name = name # public
        self._email = email  # protected
        self.__salary = salary # private, should be used inside the class

    def display_employee(self):
        print(f"name={self.name}, email={self._email}, salary={self.__salary}")


    def get_salary(self):
        return self.__salary

    def set_salary(self, salary):
        if isinstance(salary, int) and salary > 0:
            self.__salary = salary
        else:
            raise ValueError("Salary must be an integer, > 100")





emp = Employee("Ahmed","ahmed@gmail.com", 20000)
emp.display_employee()
emp.set_salary(80000)
print(emp.get_salary())
# Out:
# name=Ahmed, email=ahmed@gmail.com, salary=20000
# 80000

# %% [markdown]
# <div style="background:#e3f2fd;border-left:4px solid #1e88e5;padding:6px 10px;border-radius:6px"><b>Next cell (code)</b><br><span style="color:#546e7a">Snippet:</span> <code>class Employee:</code></div>

# %%
class Employee:
    def __init__(self, name, email, salary):
        self.name = name # public
        self._email = email  # protected
        self.__salary = salary # private, should be used inside the class

    def display_employee(self):
        print(f"name={self.name}, email={self._email}, salary={self.__salary}")


    def get_salary(self):
        return self.__salary

    def set_salary(self, salary):
        if isinstance(salary, int) and salary > 0:
            self.__salary = salary
        else:
            raise ValueError("Salary must be an integer, > 100")





emp2 = Employee("Mohamed", 'm@gmail.com', "iti")

# %% [markdown]
# <div style="background:#e3f2fd;border-left:4px solid #1e88e5;padding:6px 10px;border-radius:6px"><b>Next cell (code)</b><br><span style="color:#546e7a">Snippet:</span> <code>class Employee:</code></div>

# %%
class Employee:
    def __init__(self, name, email, salary):
        self.name = name # public
        self._email = email  # protected
        if isinstance(salary, int) and salary > 0:
            self.__salary = salary
        else:
            raise ValueError("Salary must be an integer, > 100")

    def display_employee(self):
        print(f"name={self.name}, email={self._email}, salary={self.__salary}")


    def get_salary(self):
        return self.__salary

    def set_salary(self, salary):
        if isinstance(salary, int) and salary > 0:
            self.__salary = salary
        else:
            raise ValueError("Salary must be an integer, > 100")





emp2 = Employee("Mohamed", 'm@gmail.com', "iti")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[50], line 27
#      20         else:
#      21             raise ValueError("Salary must be an integer, > 100")
# ---> 27 emp2 = Employee("Mohamed", 'm@gmail.com', "iti")
#
# Cell In[50], line 8, in Employee.__init__(self, name, email, salary)
#       6     self.__salary = salary
#       7 else:
# ----> 8     raise ValueError("Salary must be an integer, > 100")
#
# ValueError: Salary must be an integer, > 100

# %% [markdown]
# <div style="background:#e3f2fd;border-left:4px solid #1e88e5;padding:6px 10px;border-radius:6px"><b>Next cell (code)</b><br><span style="color:#546e7a">Snippet:</span> <code>class Employee:</code></div>

# %%
class Employee:
    def __init__(self, name, email, salary):
        self.name = name # public
        self._email = email  # protected
        self.set_salary(salary)

    def display_employee(self):
        print(f"name={self.name}, email={self._email}, salary={self.__salary}")


    def get_salary(self):
        return self.__salary

    def set_salary(self, salary):
        if isinstance(salary, int) and salary > 0:
            self.__salary = salary
        else:
            raise ValueError("Salary must be an integer, > 100")





emp2 = Employee("Mohamed", 'm@gmail.com', "iti")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[51], line 24
#      17         else:
#      18             raise ValueError("Salary must be an integer, > 100")
# ---> 24 emp2 = Employee("Mohamed", 'm@gmail.com', "iti")
#
# Cell In[51], line 5, in Employee.__init__(self, name, email, salary)
#       3 self.name = name # public
#       4 self._email = email  # protected
# ----> 5 self.set_salary(salary)
#
# Cell In[51], line 18, in Employee.set_salary(self, salary)
#      16     self.__salary = salary
#      17 else:
# ---> 18     raise ValueError("Salary must be an integer, > 100")
#
# ValueError: Salary must be an integer, > 100

# %% [markdown]
# <div style="background:#e3f2fd;border-left:4px solid #1e88e5;padding:6px 10px;border-radius:6px"><b>Next cell (code)</b><br><span style="color:#546e7a">Snippet:</span> <code>class Employee:</code></div>

# %%
class Employee:
    def __init__(self, name, email, salary):
        self.name = name # public
        self._email = email  # protected
        self.set_salary(salary)

    def display_employee(self):
        print(f"name={self.name}, email={self._email}, salary={self.__salary}")

    """ setting and getting the value of the private property __salary """
    def get_salary(self):
        return self.__salary

    def set_salary(self, salary):
        if isinstance(salary, int) and salary > 0:
            self.__salary = salary
        else:
            raise ValueError("Salary must be an integer, > 100")

emp2 = Employee("Mohamed", 'm@gmail.com', 1000)
print(emp2.get_salary())
# Out:
# 1000

# %% [markdown]
# <div style="background:#e3f2fd;border-left:4px solid #1e88e5;padding:6px 10px;border-radius:6px"><b>Next cell (code)</b><br><span style="color:#546e7a">Snippet:</span> <code>class Employee:</code></div>

# %%
class Employee:
    def __init__(self, name, email, salary):
        self.name = name # public
        self._email = email  # protected
        self.set_salary(salary)

    def display_employee(self):
        print(f"name={self.name}, email={self._email}, salary={self.__salary}")

    """ setting and getting the value of the private property __salary """
    def get_salary(self):
        return self.__salary

    def set_salary(self, salary):
        if isinstance(salary, int) and salary > 0:
            self.__salary = salary
        else:
            raise ValueError("Salary must be an integer, > 100")

    @property
    def salary(self):
        return self.__salary

emp2 = Employee("Mohamed", 'm@gmail.com', 1000)
print(emp2.salary)
# Out:
# 1000

# %% [markdown]
# <div style="background:#e3f2fd;border-left:4px solid #1e88e5;padding:6px 10px;border-radius:6px"><b>Next cell (code)</b><br><span style="color:#546e7a">Snippet:</span> <code>class Employee:</code></div>

# %%
class Employee:
    def __init__(self, name, email, salary):
        self.name = name # public
        self._email = email  # protected
        self.set_salary(salary)

    def display_employee(self):
        print(f"name={self.name}, email={self._email}, salary={self.__salary}")

    """ setting and getting the value of the private property __salary """

    def set_salary(self, salary):
        if isinstance(salary, int) and salary > 0:
            self.__salary = salary
        else:
            raise ValueError("Salary must be an integer, > 100")

    @property
    def salary(self):
        return self.__salary

    @salary.setter
    def salary(self, salary):
        if isinstance(salary, int) and salary > 0:
            self.__salary = salary
        else:
            raise ValueError("Salary must be an integer, > 100")



emp2 = Employee("Mohamed", 'm@gmail.com', 1000)
print(emp2.salary)
emp2.salary = 80000
print(emp2.salary)
# Out:
# 1000
# 80000

# %% [markdown]
# <div style="background:#e3f2fd;border-left:4px solid #1e88e5;padding:6px 10px;border-radius:6px"><b>Next cell (code)</b><br><span style="color:#546e7a">Snippet:</span> <code>class Employee:</code></div>

# %%
class Employee:
    def __init__(self, name, email, salary):
        self.name = name # public
        self._email = email  # protected
        if isinstance(salary, int) and salary > 0:
            self.__salary = salary
        else:
            raise ValueError("Salary must be an integer, > 100")

    def display_employee(self):
        print(f"name={self.name}, email={self._email}, salary={self.__salary}")

    """ setting and getting the value of the private property __salary """
    @property
    def salary(self):
        return self.__salary

    @salary.setter
    def salary(self, salary):
        if isinstance(salary, int) and salary > 0:
            self.__salary = salary
        else:
            raise ValueError("Salary must be an integer, > 100")



emp2 = Employee("Mohamed", 'm@gmail.com', 1000)
print(emp2.salary)
emp2.salary = 80000
print(emp2.salary)

# %% [markdown]
# <div style="background:#e3f2fd;border-left:4px solid #1e88e5;padding:6px 10px;border-radius:6px"><b>Next cell (code)</b><br><span style="color:#546e7a">Snippet:</span> <code>class Employee:</code></div>

# %%
class Employee:
    def __init__(self, name, email, salary):
        self.name = name # public
        self._email = email  # protected
        self.salary = salary

    def display_employee(self):
        print(f"name={self.name}, email={self._email}, salary={self.__salary}")

    """ setting and getting the value of the private property __salary """
    @property
    def salary(self):
        return self.__salary

    @salary.setter
    def salary(self, salary):
        if isinstance(salary, int) and salary > 0:
            self.__salary = salary
        else:
            raise ValueError("Salary must be an integer, > 100")



emp2 = Employee("Mohamed", 'm@gmail.com', 1000)
print(emp2.salary)
emp2.salary = 80000
print(emp2.salary)
# Out:
# 1000
# 80000

# %% [markdown]
# <div style="background:#e3f2fd;border-left:4px solid #1e88e5;padding:6px 10px;border-radius:6px"><b>Next cell (code)</b><br><span style="color:#546e7a">Snippet:</span> <code>class Employee:</code></div>

# %%
class Employee:
    def __init__(self, name, email, salary):
        self.name = name # public
        self._email = email  # protected
        self.salary = salary

    def display_employee(self):
        print(f"name={self.name}, email={self._email}, salary={self.__salary}")

    """ setting and getting the value of the private property __salary """
    @property
    def salary(self):
        return self.__salary

    @salary.setter
    def salary(self, salary):
        if isinstance(salary, int) and salary > 0:
            self.__salary = salary
        else:
            raise ValueError("Salary must be an integer, > 100")

    @property
    def full_name(self):
        return self.name.title()



emp2 = Employee("mohamed ahmed", 'm@gmail.com', 1000)
print(emp2.salary)
emp2.salary = 80000
print(emp2.salary)
print(emp2.full_name)
emp2.full_name = "Noha shehab"
# Out:
# 1000
# 80000
# Mohamed Ahmed
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[61], line 33
#      31 print(emp2.salary)
#      32 print(emp2.full_name)
# ---> 33 emp2.full_name = "Noha shehab"
#
# AttributeError: property 'full_name' of 'Employee' object has no setter

# %% [markdown]
# <div style="background:#e3f2fd;border-left:4px solid #1e88e5;padding:6px 10px;border-radius:6px"><b>Next cell (code)</b><br><span style="color:#546e7a">Snippet:</span> <code>print(emp2.__dict__)</code></div>

# %%
print(emp2.__dict__)
# Out:
# {'name': 'mohamed ahmed', '_email': 'm@gmail.com', '_Employee__salary': 80000}

# %% [markdown]
# <div style="background:#e3f2fd;border-left:4px solid #1e88e5;padding:6px 10px;border-radius:6px"><b>Next cell (code)</b><br><span style="color:#546e7a">Snippet:</span> <code>class Employee:</code></div>

# %%
class Employee:
    def __init__(self, name, email, salary):
        self.name = name # public
        self._email = email  # protected
        self.salary = salary

    def display_employee(self):
        print(f"name={self.name}, email={self._email}, salary={self.__salary}")

    """ setting and getting the value of the private property __salary """
    @property
    def salary(self):
        return self.__salary

    @salary.setter
    def salary(self, salary):
        if isinstance(salary, int) and salary > 0:
            self.__salary = salary
        else:
            raise ValueError("Salary must be an integer, > 100")

    @salary.deleter
    def salary(self):
        """ del obj.salary"""
        pass

    @property
    def full_name(self):
        return self.name.title()

# %% [markdown]
# <div style="background:#f3e5f5;border-left:4px solid #8e24aa;padding:6px 10px;border-radius:6px"><b>Next cell (markdown)</b><br><span style="color:#546e7a">Text:</span> # Abstraction</div>

# %% [markdown]
# # Abstraction

# %% [markdown]
# <div style="background:#e3f2fd;border-left:4px solid #1e88e5;padding:6px 10px;border-radius:6px"><b>Next cell (code)</b><br><span style="color:#546e7a">Snippet:</span> <code>from abc import abstractmethod, ABC</code></div>

# %%
from abc import abstractmethod, ABC

""" any abstract class in python
must inherits from ABC class and has at least one abstract method.
"""
class Base:
    @abstractmethod
    def test(self):pass

b= Base()

# %% [markdown]
# <div style="background:#e3f2fd;border-left:4px solid #1e88e5;padding:6px 10px;border-radius:6px"><b>Next cell (code)</b><br><span style="color:#546e7a">Snippet:</span> <code>Empty cell</code></div>

# %% [markdown]
# <div style="background:#e3f2fd;border-left:4px solid #1e88e5;padding:6px 10px;border-radius:6px"><b>Next cell (code)</b><br><span style="color:#546e7a">Snippet:</span> <code>class Person(ABC):</code></div>

# %%
class Person(ABC):
    def test(self):pass

p = Person()

# %% [markdown]
# <div style="background:#e3f2fd;border-left:4px solid #1e88e5;padding:6px 10px;border-radius:6px"><b>Next cell (code)</b><br><span style="color:#546e7a">Snippet:</span> <code>class Car(ABC):</code></div>

# %%
class Car(ABC):
    @abstractmethod
    def move(self):pass

c = Car()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[66], line 5
#       2     @abstractmethod
#       3     def move(self):pass
# ----> 5 c = Car()
#
# TypeError: Can't instantiate abstract class Car without an implementation for abstract method 'move'

# %% [markdown]
# <div style="background:#e3f2fd;border-left:4px solid #1e88e5;padding:6px 10px;border-radius:6px"><b>Next cell (code)</b><br><span style="color:#546e7a">Snippet:</span> <code>class QueueOutOfRangeException(Exception):</code></div>

# %%
class QueueOutOfRangeException(Exception):
    pass
