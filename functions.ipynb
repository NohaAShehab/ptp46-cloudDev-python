# %% [markdown]
# ## 🎯 Functions with Pre-defined Arguments
# > 📝 **Introduction:** Functions can be defined with a specific number of required arguments

# %% [markdown]
# # function with pre-define number of required arguments

# %% [markdown]
# ## 🏗️ Basic Function Definition with Pass
# > 🚀 **Creating functions:** Define a function with `def` keyword. Using `pass` returns `None` by default

# %%
# define function

def say_hello ():
    pass

# calling function
res = say_hello()
print(res)
# Out:
# None

# %%
def say_hi():
    return

res2= say_hi()
print(res2)
# Out:
# None

# %% [markdown]
# ## 🔙 Function with Return Statement
# > ↩️ **Empty return:** Using `return` without a value also returns `None`

# %%
print(type(say_hi))
# Out:
# <class 'function'>

# %%
def say_welcome():
    username = input("Enter your name: ")
    print(f"welcome {username}")

res3 = say_welcome()
print(res3)
# Out:
# welcome Ahmed
# None

# %% [markdown]
# ## 🔍 Checking Function Type
# > 🏷️ **Type verification:** Functions are first-class objects in Python with type 'function'

# %%
def get_full_name():
    first_name = input("Enter your first name: ")
    last_name = input("Enter your last name: ")
    fullname = f'{first_name} {last_name}'
    return fullname

username = get_full_name()
print(username)
# Out:
# Noha Shehab

# %%
def get_full_name2():
    first_name = input("Enter your first name: ")
    last_name = input("Enter your last name: ")
    fullname = f'{first_name} {last_name}'
    return  first_name, last_name, fullname # tuple

username2 = get_full_name2()
print(username2)
# Out:
# ('a', 'b', 'a b')

# %% [markdown]
# ## 👋 Function with User Input (No Return)
# > 📥 **Input and print:** Function takes user input and prints a message but returns `None`

# %%
# function require params

def sum_num(num1, num2):
    res = num1 + num2
    print(f'res= {res}')
    return res

sum_num(3,4)
# Out:
# 7

# %%
sum_num(4,45,5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 sum_num(4,45,5)
#
# TypeError: sum_num() takes 2 positional arguments but 3 were given

# %% [markdown]
# ## ✨ Function Returning a Value
# > 🎁 **Returning data:** Function that processes input and returns a meaningful result

# %%
sum_num(4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 sum_num(4)
#
# TypeError: sum_num() missing 1 required positional argument: 'num2'

# %% [markdown]
# ## 📦 Function Returning Multiple Values
# > 🎪 **Tuple unpacking:** Return multiple values as a tuple from a function

# %% [markdown]
# # define function with defaults parameters

# %% [markdown]
# ## ➕ Function with Required Parameters
# > 📌 **Parameters:** Define functions that require specific arguments to be passed

# %%
def sum_num2(num1, num2=10):
    print(f"num1={num1}, num2={num2}")
    res = num1 + num2
    print(f'res= {res}')
    return res

sum_num2(3,4)
sum_num2(3)
# Out:
# 13

# %% [markdown]
# ## 🎯 Default Parameters
# > 💫 **Optional arguments:** Functions can have default parameter values for flexibility

# %% [markdown]
# ## 🖨️ Print Function Default Separator
# > 🔗 **Default behavior:** `print()` separates multiple values with a space by default

# %%
print(4,5,63)
# Out:
# 4 5 63

# %%
print(4,5,63, sep='|')
# Out:
# 4|5|63

# %% [markdown]
# ## ❌ Error: Too Many Arguments
# > ⚠️ **TypeError:** Calling a function with more arguments than defined causes an error

# %%
print("Hello")
print("World")
# Out:
# Hello
# World

# %%
print("Hello", end='$')
print("World")
# Out:
# Hello$World

# %% [markdown]
# ## ❌ Error: Missing Required Argument
# > ⚠️ **TypeError:** Calling a function without required arguments causes an error

# %% [markdown]
# ## ⚠️ Syntax Error: Non-default After Default
# > 🚫 **Invalid syntax:** Default parameters must come after non-default parameters in function definition

# %%
def sum_num3(num1=100, num2):
    print(f"num1={num1}, num2={num2}")
    res = num1 + num2
    print(f'res= {res}')
    return res
# Out:
#   Cell In[16], line 1
#     def sum_num3(num1=100, num2):
#                            ^
# SyntaxError: parameter without a default follows parameter with a default

# %% [markdown]
# ## 🔢 Using Default Parameters
# > ✅ **Flexibility:** Call with all arguments or use defaults for optional ones

# %% [markdown]
# ## 🔧 Custom Separator in Print
# > 🎨 **Customization:** Use the `sep` parameter to change how values are separated

# %% [markdown]
# ## 📝 Default Print Behavior (Newline)
# > ⬇️ **Line breaks:** By default, `print()` adds a newline after each statement

# %% [markdown]
# ## 🔗 Custom End Character in Print
# > ➡️ **Same line printing:** Use the `end` parameter to change what appears after print output

# %% [markdown]
# ## 🔗No validation on the data type ?
# > ➡️ ** You must add the validation rules in the function.

# %%
def mul_nums(num1, num2):
    print(f"num1={num1}, num2={num2}")
    res = num1 * num2
    print(f'res= {res}')
    return res

# %%
mul_nums(3,4)
# Out:
# 12

# %%
mul_nums("iti", 3 )
# Out:
# 'itiitiiti'

# %%
mul_nums("iti",'cloud')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 mul_nums("iti",'cloud')
#
# Cell In[17], line 3, in mul_nums(num1, num2)
#       1 def mul_nums(num1, num2):
#       2     print(f"num1={num1}, num2={num2}")
# ----> 3     res = num1 * num2
#       4     print(f'res= {res}')
#       5     return res
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
def mul_nums(num1:int, num2:int) ->int:
    print(f"num1={num1}, num2={num2}")
    res = num1 * num2
    print(f'res= {res}')
    return res

mul_nums(3,4)
# Out:
# 12

# %%
mul_nums("iti", 3 ) # Expected type 'int', got 'str' instead
# Out:
# 'itiitiiti'

# %%
mul_nums('iti', "test")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 mul_nums('iti', "test")
#
# Cell In[21], line 3, in mul_nums(num1, num2)
#       1 def mul_nums(num1:int, num2:int) ->int:
#       2     print(f"num1={num1}, num2={num2}")
# ----> 3     res = num1 * num2
#       4     print(f'res= {res}')
#       5     return res
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
# manually add validation ?
def mul_nums(num1:int, num2:int) -> int:
    """
    :param num1: must be integer
    :param num2: must be integer
    :return: the multiplication of num1 and num2
    """
    print(f"num1={num1}, num2={num2}")
    res = num1 * num2
    print(f'res= {res}')
    return res

mul_nums(3,4)

# %%
# manually add validation ?
def mul_nums(num1:int, num2:int) -> int:
    """
    :param num1: must be integer
    :param num2: must be integer
    :return: the multiplication of num1 and num2
    """
    if type(num1) == int and type(num2) == int:
        print(f"num1={num1}, num2={num2}")
        res = num1 * num2
        print(f'res= {res}')
        return res
    print(f"num1={num1}, num2={num2} must be integer")
mul_nums(3,4)
# Out:
# 12

# %%
mul_nums(3,"iti")
# Out:
# num1=3, num2=iti must be integer

# %%
print(isinstance(44,int))
# Out:
# True

# %%
# manually add validation ?
def mul_nums(num1:int, num2:int) -> int:
    """
    :param num1: must be integer
    :param num2: must be integer
    :return: the multiplication of num1 and num2
    """
    if isinstance(num1, int) and isinstance(num2, int):
        print(f"num1={num1}, num2={num2}")
        res = num1 * num2
        print(f'res= {res}')
        return res

    print(f"num1={num1}, num2={num2} must be integer")
    return False

mul_nums("3",4)
# Out:
# False

# %%
mul_nums("iti", 3)
# Out:
# False

# %%
new  = mul_nums("titi",4)
# Out:
# num1=titi, num2=4 must be integer

# %%
# manually add validation ?
def mul_nums(num1:int, num2:int) -> int:
    """
    :param num1: must be integer
    :param num2: must be integer
    :return: the multiplication of num1 and num2
    """
    if isinstance(num1, int) and isinstance(num2, int):
        print(f"num1={num1}, num2={num2}")
        res = num1 * num2
        print(f'res= {res}')
        return res

    print(f"num1={num1}, num2={num2} must be integer")


mul_nums("3",4)
# Out:
# num1=3, num2=4 must be integer

# %%
mul_nums(323, [23,34,3])
# Out:
# num1=323, num2=[23, 34, 3] must be integer

# %%
mul_nums("iti", {"name":"ali"})
# Out:
# num1=iti, num2={'name': 'ali'} must be integer

# %%
number= input("please enter a number")
if number.isdigit(): # with string
    number=  int(number)

# %%
# all datatypes in python are classes ??
print(isinstance([23,323], tuple))
# Out:
# False

# %% [markdown]
# ## functions with unknow number of parameters

# %%
print()
print(34)
print(44,344,344)
# Out:
# 34
# 44 344 344

# %%
def apply_for_job(applications):
    print(applications)

apply_for_job("Noha")
# Out:
# Noha

# %%
apply_for_job("Ahmed", "Mohamed", "ALI")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 apply_for_job("Ahmed", "Mohamed", "ALI")
#
# TypeError: apply_for_job() takes 1 positional argument but 3 were given

# %%
apply_for_job()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 apply_for_job()
#
# TypeError: apply_for_job() missing 1 required positional argument: 'applications'

# %%
def apply_for_job(*applications): # *- --> zero or more 
    print(applications)
    
apply_for_job("Noha")
apply_for_job()
apply_for_job("Ahmed", "Mohamed", "ALI")
# Out:
# ('Noha',)
# ()
# ('Ahmed', 'Mohamed', 'ALI')

# %%
def introduce_your_self(info):
    print(info)

# %%
introduce_your_self(name='ahmed')
introduce_your_self()
introduce_your_self(fname='ali', lastName='ahmed')

# %%
def introduce_your_self(**info): # allow accept params key=value
    print(info) 
introduce_your_self(name='ahmed')
introduce_your_self()
introduce_your_self(fname='ali', lastName='ahmed')
# Out:
# {'name': 'ahmed'}
# {}
# {'fname': 'ali', 'lastName': 'ahmed'}
