# %% [markdown]
# <div style="background:rgba(14,165,233,0.08);border:1px solid rgba(14,165,233,0.35);border-left:4px solid rgba(14,165,233,0.9);padding:10px 12px;border-radius:8px;">
# <strong style="color:inherit;">Hello World Output</strong><br>
# <span style="color:inherit;">Print a simple greeting to verify the notebook is running.</span>
# </div>

# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# <div style="background:rgba(14,165,233,0.08);border:1px solid rgba(14,165,233,0.35);border-left:4px solid rgba(14,165,233,0.9);padding:10px 12px;border-radius:8px;">
# <strong style="color:inherit;">Multi-Line String Concatenation</strong><br>
# <span style="color:inherit;">Build a bio string across lines and print the final result.</span>
# </div>

# %%
name= "Ahmed"
bio = ("My name is Ahmed, I works at "
       "Vois,"
       "I lives in Cairo")

print(bio)
# Out:
# My name is Ahmed, I works at Vois,I lives in Cairo

# %% [markdown]
# <div style="background:rgba(14,165,233,0.08);border:1px solid rgba(14,165,233,0.35);border-left:4px solid rgba(14,165,233,0.9);padding:10px 12px;border-radius:8px;">
# <strong style="color:inherit;">Triple-Quoted Multi-Line Text</strong><br>
# <span style="color:inherit;">Create a multi-line string literal and display it with line breaks.</span>
# </div>

# %%
bio2 = '''My name is Ahmed
I works at Vois
I lives in Cairo'''
# automatically add \n upon adding entering new line
print(bio2)
# Out:
# My name is Ahmed
# I works at Vois
# I lives in Cairo

# %% [markdown]
# <div style="background:rgba(14,165,233,0.08);border:1px solid rgba(14,165,233,0.35);border-left:4px solid rgba(14,165,233,0.9);padding:10px 12px;border-radius:8px;">
# <strong style="color:inherit;">Docstring-Style Note</strong><br>
# <span style="color:inherit;">Use a triple-quoted string as a descriptive block comment.</span>
# </div>

# %%
"""
today we are exploring the basics of python syntax
and how it be used in developing different applications
"""
# Out:
# '\ntoday we are exploring the basics of python syntax \nand how it be used in developing different applications\n'

# %% [markdown]
# <div style="background:rgba(14,165,233,0.08);border:1px solid rgba(14,165,233,0.35);border-left:4px solid rgba(14,165,233,0.9);padding:10px 12px;border-radius:8px;">
# <strong style="color:inherit;">String Variable and Type</strong><br>
# <span style="color:inherit;">Assign a string and print its value alongside its type.</span>
# </div>

# %%
username = 'ali'
print(username, type(username))
# Out:
# ali <class 'str'>

# %% [markdown]
# <div style="background:rgba(14,165,233,0.08);border:1px solid rgba(14,165,233,0.35);border-left:4px solid rgba(14,165,233,0.9);padding:10px 12px;border-radius:8px;">
# <strong style="color:inherit;">Integer Assignment</strong><br>
# <span style="color:inherit;">Store a numeric value to introduce integer variables.</span>
# </div>

# %%
age = 25

# %% [markdown]
# <div style="background:rgba(14,165,233,0.08);border:1px solid rgba(14,165,233,0.35);border-left:4px solid rgba(14,165,233,0.9);padding:10px 12px;border-radius:8px;">
# <strong style="color:inherit;">Dynamic Typing and Casting</strong><br>
# <span style="color:inherit;">Show how a value changes type by converting an integer to a string.</span>
# </div>

# %%
# loosely dynamically typed lang. detect datatype in the runtime , and change to another datatype

num = 10
print(num, type(num))
# cast to string
num = str(num)
print(num, type(num))
# Out:
# 10 <class 'int'>
# 10 <class 'str'>

# %% [markdown]
# <div style="background:rgba(14,165,233,0.08);border:1px solid rgba(14,165,233,0.35);border-left:4px solid rgba(14,165,233,0.9);padding:10px 12px;border-radius:8px;">
# <strong style="color:inherit;">String to Integer Conversion</strong><br>
# <span style="color:inherit;">Convert a numeric string to an integer and print its type.</span>
# </div>

# %%
day = "31" # string
day = int(day)
print(day, type(day))
# Out:
# 31 <class 'int'>

# %% [markdown]
# <div style="background:rgba(14,165,233,0.08);border:1px solid rgba(14,165,233,0.35);border-left:4px solid rgba(14,165,233,0.9);padding:10px 12px;border-radius:8px;">
# <strong style="color:inherit;">Invalid Cast Example</strong><br>
# <span style="color:inherit;">Attempt to convert a non-numeric string to int to show a conversion error.</span>
# </div>

# %%
username = 'noha'
print(username, type(username))
username=  int(username)
print(username, type(username))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 3
#       1 username = 'noha'
#       2 print(username, type(username))
# ----> 3 username=  int(username)
#       4 print(username, type(username))
#
# ValueError: invalid literal for int() with base 10: 'noha'

# %% [markdown]
# <div style="background:rgba(14,165,233,0.08);border:1px solid rgba(14,165,233,0.35);border-left:4px solid rgba(14,165,233,0.9);padding:10px 12px;border-radius:8px;">
# <strong style="color:inherit;">Memory Size of Empty String</strong><br>
# <span style="color:inherit;">Check how many bytes an empty string occupies.</span>
# </div>

# %%
import sys

print(sys.getsizeof(""))
# Out:
# 41

# %% [markdown]
# <div style="background:rgba(14,165,233,0.08);border:1px solid rgba(14,165,233,0.35);border-left:4px solid rgba(14,165,233,0.9);padding:10px 12px;border-radius:8px;">
# <strong style="color:inherit;">Memory Size of a Short String</strong><br>
# <span style="color:inherit;">Compare size of a small string literal.</span>
# </div>

# %%
print(sys.getsizeof("hello"))
# Out:
# 46

# %% [markdown]
# <div style="background:rgba(14,165,233,0.08);border:1px solid rgba(14,165,233,0.35);border-left:4px solid rgba(14,165,233,0.9);padding:10px 12px;border-radius:8px;">
# <strong style="color:inherit;">Memory Size of an Integer</strong><br>
# <span style="color:inherit;">Inspect the byte size of a small integer.</span>
# </div>

# %%
numm= 10
print(sys.getsizeof(numm))
# Out:
# 28

# %% [markdown]
# <div style="background:rgba(14,165,233,0.08);border:1px solid rgba(14,165,233,0.35);border-left:4px solid rgba(14,165,233,0.9);padding:10px 12px;border-radius:8px;">
# <strong style="color:inherit;">Truthiness of Non-Empty Strings</strong><br>
# <span style="color:inherit;">Convert a non-empty string to a boolean value.</span>
# </div>

# %%
email = 'test@iti.com'

email=  bool(email)  # True, False
print(email, type(email))
# Out:
# True <class 'bool'>

# %% [markdown]
# <div style="background:rgba(14,165,233,0.08);border:1px solid rgba(14,165,233,0.35);border-left:4px solid rgba(14,165,233,0.9);padding:10px 12px;border-radius:8px;">
# <strong style="color:inherit;">Logical AND Behavior</strong><br>
# <span style="color:inherit;">See how Python returns the last truthy operand.</span>
# </div>

# %%
# logical operators


print("iti" and "opensource")
# Out:
# opensource

# %% [markdown]
# <div style="background:rgba(14,165,233,0.08);border:1px solid rgba(14,165,233,0.35);border-left:4px solid rgba(14,165,233,0.9);padding:10px 12px;border-radius:8px;">
# <strong style="color:inherit;">Boolean of "iti"</strong><br>
# <span style="color:inherit;">Check boolean conversion for a non-empty string.</span>
# </div>

# %%
print(bool("iti"))
# Out:
# True

# %% [markdown]
# <div style="background:rgba(14,165,233,0.08);border:1px solid rgba(14,165,233,0.35);border-left:4px solid rgba(14,165,233,0.9);padding:10px 12px;border-radius:8px;">
# <strong style="color:inherit;">Boolean of "opensource"</strong><br>
# <span style="color:inherit;">Confirm that non-empty strings are truthy.</span>
# </div>

# %%
print(bool("opensource"))
# Out:
# True

# %% [markdown]
# <div style="background:rgba(14,165,233,0.08);border:1px solid rgba(14,165,233,0.35);border-left:4px solid rgba(14,165,233,0.9);padding:10px 12px;border-radius:8px;">
# <strong style="color:inherit;">Empty Code Cell</strong><br>
# <span style="color:inherit;">Placeholder for future examples.</span>
# </div>
