# %% [markdown]
# ## 🔒 Introduction to Tuples
# > 📦 **Immutable data structure:** Tuples are like sets but immutable - once created, cannot be changed!

# %% [markdown]
# ### tuple like a set but immutable data once create cannot be changed

# %% [markdown]
# <div style="background:rgba(14,165,233,0.08);border:1px solid rgba(14,165,233,0.35);border-left:4px solid rgba(14,165,233,0.9);padding:10px 12px;border-radius:8px;">
# <strong style="color:inherit;">Create Empty tuples</strong><br>
# <span style="color:inherit;">Initialize empty tuple variables.</span>
# </div>

# %%
t = tuple()
myt = ()

# %% [markdown]
# <div style="background:rgba(14,165,233,0.08);border:1px solid rgba(14,165,233,0.35);border-left:4px solid rgba(14,165,233,0.9);padding:10px 12px;border-radius:8px;">
# <strong style="color:inherit;">Mixed-Type tuple</strong><br>
# <span style="color:inherit;">Create a tuple with various data types.</span>
# </div>

# %%
myt = ("iti", 32, 324.3, True, ["python", "kubernates", 'jenkins'], None , "iti")
print(myt)
# Out:
# ('iti', 32, 324.3, True, ['python', 'kubernates', 'jenkins'], None, 'iti')

# %% [markdown]
# <div style="background:rgba(14,165,233,0.08);border:1px solid rgba(14,165,233,0.35);border-left:4px solid rgba(14,165,233,0.9);padding:10px 12px;border-radius:8px;">
# <strong style="color:inherit;">tuple Length</strong><br>
# <span style="color:inherit;">Count the number of elements in the tuple.</span>
# </div>

# %%
print(len(myt))
# Out:
# 7

# %% [markdown]
# <div style="background:rgba(14,165,233,0.08);border:1px solid rgba(14,165,233,0.35);border-left:4px solid rgba(14,165,233,0.9);padding:10px 12px;border-radius:8px;">
# <strong style="color:inherit;">Count a Value</strong><br>
# <span style="color:inherit;">Count how many times a value appears.</span>
# </div>

# %%
print(myt.count("iti"))
# Out:
# 2

# %% [markdown]
# <div style="background:rgba(14,165,233,0.08);border:1px solid rgba(14,165,233,0.35);border-left:4px solid rgba(14,165,233,0.9);padding:10px 12px;border-radius:8px;">
# <strong style="color:inherit;">Index Access</strong><br>
# <span style="color:inherit;">Retrieve an element by its index.</span>
# </div>

# %%
# get element at index
myt[2]
# Out:
# 324.3

# %% [markdown]
# <div style="background:rgba(14,165,233,0.08);border:1px solid rgba(14,165,233,0.35);border-left:4px solid rgba(14,165,233,0.9);padding:10px 12px;border-radius:8px;">
# <strong style="color:inherit;">Find Index</strong><br>
# <span style="color:inherit;">Locate the first occurrence of a value.</span>
# </div>

# %%
# get index of element
print(myt.index("iti"))
# Out:
# 0

# %% [markdown]
# <div style="background:rgba(14,165,233,0.08);border:1px solid rgba(14,165,233,0.35);border-left:4px solid rgba(14,165,233,0.9);padding:10px 12px;border-radius:8px;">
# <strong style="color:inherit;">Iterate Items</strong><br>
# <span style="color:inherit;">Loop through tuple elements.</span>
# </div>

# %%
# tuple is iterable
for item in myt:
    print(f"item = {item} ")
# Out:
# item = iti
# item = 32
# item = 324.3
# item = True
# item = ['python', 'kubernates', 'jenkins']
# item = None
# item = iti

# %% [markdown]
# <div style="background:rgba(14,165,233,0.08);border:1px solid rgba(14,165,233,0.35);border-left:4px solid rgba(14,165,233,0.9);padding:10px 12px;border-radius:8px;">
# <strong style="color:inherit;">Enumerate Items</strong><br>
# <span style="color:inherit;">Loop with index and value pairs.</span>
# </div>

# %%
for index,  item in enumerate(myt):
    print(f"index : {index} .. item = {item} ")
# Out:
# index : 0 .. item = iti
# index : 1 .. item = 32
# index : 2 .. item = 324.3
# index : 3 .. item = True
# index : 4 .. item = ['python', 'kubernates', 'jenkins']
# index : 5 .. item = None
# index : 6 .. item = iti

# %% [markdown]
# <div style="background:rgba(14,165,233,0.08);border:1px solid rgba(14,165,233,0.35);border-left:4px solid rgba(14,165,233,0.9);padding:10px 12px;border-radius:8px;">
# <strong style="color:inherit;">Membership Test</strong><br>
# <span style="color:inherit;">Check if a value exists in the tuple.</span>
# </div>

# %%
# element exists in tuple ?
print("noha" in myt)
# Out:
# False

# %% [markdown]
# <div style="background:rgba(14,165,233,0.08);border:1px solid rgba(14,165,233,0.35);border-left:4px solid rgba(14,165,233,0.9);padding:10px 12px;border-radius:8px;">
# <strong style="color:inherit;">Mutability Reminder</strong><br>
# <span style="color:inherit;">Note that tuples are immutable in Python.</span>
# </div>

# %% [markdown]
# <div style="background:rgba(14,165,233,0.08);border:1px solid rgba(14,165,233,0.35);border-left:4px solid rgba(14,165,233,0.9);padding:10px 12px;border-radius:8px;">
# <strong style="color:inherit;">Nested tuple Access</strong><br>
# <span style="color:inherit;">Access an element inside a nested tuple.</span>
# </div>

# %%
print(myt[3][1])
# Out:
# kubernates

# %%
myt[4].append("microservice")

# %% [markdown]
# <div style="background:rgba(14,165,233,0.08);border:1px solid rgba(14,165,233,0.35);border-left:4px solid rgba(14,165,233,0.9);padding:10px 12px;border-radius:8px;">
# <strong style="color:inherit;">Concatenate tuples</strong><br>
# <span style="color:inherit;">Join two tuples using + and +=.</span>
# </div>

# %%
# concat 2 tuples # create new tuple
t1 = [23,2,43]
t2 = [23,'24','dsd']
t3 = t1+t2
print(t3)

t1 += t2 # re-assign ,,, l1 = l1+l2
# Out:
# [23, 2, 43, 23, '24', 'dsd']

# %% [markdown]
# <div style="background:rgba(14,165,233,0.08);border:1px solid rgba(14,165,233,0.35);border-left:4px solid rgba(14,165,233,0.9);padding:10px 12px;border-radius:8px;">
# <strong style="color:inherit;">Minimum Value</strong><br>
# <span style="color:inherit;">Find the smallest number in a tuple.</span>
# </div>

# %%
x = (5,66,77)
print(min(x))
# Out:
# 5

# %% [markdown]
# <div style="background:rgba(14,165,233,0.08);border:1px solid rgba(14,165,233,0.35);border-left:4px solid rgba(14,165,233,0.9);padding:10px 12px;border-radius:8px;">
# <strong style="color:inherit;">String to tuple</strong><br>
# <span style="color:inherit;">Convert a string into a tuple of characters.</span>
# </div>

# %%
# cast string to a tuple
message = 'The lecture is interesting'
print(tuple(message))
# Out:
# ('T', 'h', 'e', ' ', 'l', 'e', 'c', 't', 'u', 'r', 'e', ' ', 'i', 's', ' ', 'i', 'n', 't', 'e', 'r', 'e', 's', 't', 'i', 'n', 'g')

# %% [markdown]
# <div style="background:rgba(14,165,233,0.08);border:1px solid rgba(14,165,233,0.35);border-left:4px solid rgba(14,165,233,0.9);padding:10px 12px;border-radius:8px;">
# <strong style="color:inherit;">Create tuple of one item</strong><br>
# <span style="color:inherit;">.....</span>
# </div>

# %%
name = ("noha") # Remove redundant parentheses
print(type(name), name)
# Out:
# <class 'str'> noha

# %%
name = tuple("noha") # Remove redundant parentheses
print(type(name), name)
# Out:
# <class 'tuple'> ('n', 'o', 'h', 'a')

# %%
name = tuple(["noha"]) # Remove redundant parentheses
print(type(name), name)
# Out:
# <class 'tuple'> ('noha',)

# %%
name = ("noha",) # Remove redundant parentheses
print(type(name), name)
# Out:
# <class 'tuple'> ('noha',)
